# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results.csv")
df.describe()
# Out:
#                 row           run    num_shards   num_threads      num_dims  \
# count  44000.000000  44000.000000  44000.000000  44000.000000  44000.000000
# mean   22000.500000    999.500000      9.301773     15.959500    830.454545
# std    12701.850259    577.356758     10.703334      9.021237    370.174159
# min        1.000000      0.000000      1.000000      1.000000    384.000000
# 25%    11000.750000    499.750000      2.000000      8.000000    784.000000
# 50%    22000.500000    999.500000      4.000000     16.000000    785.000000
# 75%    33000.250000   1499.250000     10.000000     24.000000    786.000000
# max    44000.000000   1999.000000     40.000000     31.000000   1536.000000
#
#         num_vectors        weight  cost_per_vector  cost_per_scatter  \
# count  4.400000e+04  4.400000e+04     44000.000000      44000.000000
# mean   1.722730e+07  1.123893e+10        25.247196         50.637003
# std    1.451011e+07  6.884814e+09        14.418548         28.906415
# ...

# %%
corr = df.corr()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Greens",annot=True);

# %%
df.plot.scatter(x = 'cost_per_scatter', y = 'duration', s = 1);

# %%
df.plot.scatter(x = 'cost_per_vector', y = 'duration', s = 1);

# %%
df.plot.scatter(x = 'num_shards', y = 'duration', s = 1);

# %%
df.plot.scatter(x = 'num_threads', y = 'duration', s = 1);
